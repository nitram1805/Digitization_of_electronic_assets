# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_parquet('Data/pump_station_data.parquet')
data = data[:]["2023-02-14":"2023-02-16"]
print(data)
print(data.columns)
fig, ax = plt.subplots(2)
ax[0].plot(data['outflow'])
ax[1].plot(data['height'])
fig.show
fig, ax = plt.subplots(2)
ax[0].plot(data['pump1_rpm'])
ax[1].plot(data['pump1_power'])
fig.show
# Out:
#                                   height  outflow  pump1_rpm  pump1_power  \
# time
# 2023-02-14 00:00:00.342000+00:00   155.0    316.0        0.0          0.0
# 2023-02-14 00:00:01.342000+00:00   155.0    317.0        0.0          0.0
# 2023-02-14 00:00:02.342000+00:00   155.0    319.0        0.0          0.0
# 2023-02-14 00:00:03.342000+00:00   155.0    318.0        0.0          0.0
# 2023-02-14 00:00:04.342000+00:00   155.0    312.0        0.0          0.0
# ...                                  ...      ...        ...          ...
# 2023-02-16 23:59:55.342000+00:00   154.0    244.0        0.0          0.0
# 2023-02-16 23:59:56.342000+00:00   154.0    244.0        0.0          0.0
# 2023-02-16 23:59:57.342000+00:00   154.0    247.0        0.0          0.0
# 2023-02-16 23:59:58.342000+00:00   154.0    247.0        0.0          0.0
# 2023-02-16 23:59:59.342000+00:00   154.0    247.0        0.0          0.0
#
#                                   pump4_rpm  pump4_power
# time
# ...

# %%
fig, ax = plt.subplots()
timeStart = "2023-02-14 15:30:00.342000+00:00"
timeStop = "2023-02-14 22:30:00.342000+00:00"
ax.plot(data['height'][timeStart:timeStop]-70, color='red')
#ax.plot(data['pump1_power'][timeStart:timeStop], color='green')
#ax.plot(data['pump4_power'][timeStart:timeStop], color='blue')
ax.plot(data['pump4_rpm'][timeStart:timeStop]*0.05, color='orange')
fig.show()
# Out:
# /tmp/ipykernel_8367/1485258287.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
